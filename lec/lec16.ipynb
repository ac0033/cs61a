# %%
a = [1, 2, 3]

# %%
b=[a, 4]

# %%
c = iter(a)

# %%
d = c

# %%
next(c)
# Out:
# 1

# %%
next(d)
# Out:
# 2

# %%
b
# Out:
# [[1, 2, 3], 4]

# %%
all(map(print, range(-3, 3)))
# Out:
# -3
# False

# %%
def average(s):
    """Return the average of values in a list."""
    return sum(s) / len(list(s))

# %%
average(map(lambda x: x * x, [3, 4, 5, 6])) #iterator一次性消耗
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 average(map(lambda x: x * x, [3, 4, 5, 6]))
#
# Cell In[17], line 3, in average(s)
#       1 def average(s):
#       2     """Return the average of values in a list."""
# ----> 3     return sum(s) / len(list(s))
#
# ZeroDivisionError: division by zero
